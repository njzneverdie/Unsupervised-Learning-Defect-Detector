# %% [markdown]
# 1. 經典無監督 (PCA + K-means / GMM) 做 microstructure clustering + 異常分數
#
# 2. CNN Autoencoder 做 patch-level anomaly detection（主角）
#
# 3. Self-supervised 表徵學習 + One-Class SVM / Isolation Forest

# %% [markdown]
# $$整個計畫的目標$$
# 輸入: 一張 SEM 影像
#
# 輸出:
#
# *   一張 anomaly heatmap 顯示哪裡可能是孔洞、夾雜、異常晶粒、加工缺縣
#
#
# *   或標示這張圖是「正常 microstructure」還是「有可疑缺陷」。

# %% [markdown]
# $$在 Colab 自動建立 kaggle.json$$

# %%
import json, os

# 請將你的 kaggle.json 上傳到 Colab，勿將 key 直接寫在 notebook
# kaggle.json 可從 https://www.kaggle.com/settings -> API -> Create New Token 下載
kaggle_json_path = "/root/.kaggle/kaggle.json"
if not os.path.exists(kaggle_json_path):
    from google.colab import files
    print("請上傳你的 kaggle.json")
    uploaded = files.upload()
    os.makedirs("/root/.kaggle", exist_ok=True)
    with open(kaggle_json_path, "wb") as f:
        f.write(uploaded["kaggle.json"])
    os.chmod(kaggle_json_path, 0o600)
print("Kaggle credentials ready.")

# %% [markdown]
# $$安裝 Kaggle CLI$$

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %% [markdown]
# https://www.kaggle.com/datasets/dragonzhang/grainsize-train?resource=download

# %% [markdown]
# $$下載指定 dataset$$

# %%
# !kaggle datasets download -d dragonzhang/grainsize-train
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dragonzhang/grainsize-train
# License(s): unknown
# Downloading grainsize-train.zip to /content
# 100% 1.66G/1.66G [00:23<00:00, 105MB/s]
# 100% 1.66G/1.66G [00:23<00:00, 76.4MB/s]

# %% [markdown]
# $$解壓縮 Dataset$$

# %%
# !unzip -q grainsize-train.zip -d grainsize_dataset

# %%
from pathlib import Path
import cv2
import numpy as np
import matplotlib.pyplot as plt

DATA_ROOT = Path("/content/grainsize_dataset")
IMG_EXT = [".jpg", ".png", ".jpeg", ".tif", ".tiff"]

image_paths = [p for p in DATA_ROOT.rglob("*") if p.suffix.lower() in IMG_EXT]
print("共有影像張數：", len(image_paths))
image_paths[:5]
# Out:
# 共有影像張數： 4222
# [PosixPath('/content/grainsize_dataset/train/10.0/152-100-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/126-102-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/146-101-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/194-101-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/182-101-10.0-500x.jpg')]

# %% [markdown]
# 簡單看一張圖確認：

# %%
img0 = cv2.imread(str(image_paths[0]), cv2.IMREAD_GRAYSCALE)
plt.imshow(img0, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1375.5), np.float64(1103.5), np.float64(-0.5))

# %% [markdown]
# $1. Preprocessing：灰階 + Normalize +縮放$

# %%
def preprocess_image(path, resize_to=(512, 512)):
    img = cv2.imread(str(path), cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Cannot read image: {path}")

    if resize_to is not None:
        img = cv2.resize(img, resize_to, interpolation=cv2.INTER_AREA)

    # 轉成 float32 然後做 normalize
    img = img.astype(np.float32) / 255.0

    return img

# 測試
img = preprocess_image(image_paths[0], resize_to=None)
print("shape:", img.shape, "min:", img.min(), "max:", img.max())
plt.imshow(img, cmap='gray')
plt.axis('off')
# Out:
# shape: (1104, 1376) min: 0.043137256 max: 0.80784315
# (np.float64(-0.5), np.float64(1375.5), np.float64(1103.5), np.float64(-0.5))

# %% [markdown]
# 2. 切 Patch 的函式

# %%
def extract_patches(img, patch_size=64, stride=32):

    H, W = img.shape
    patches = []
    coords = []

    for y in range(0, H - patch_size + 1, stride):
        for x in range(0, W - patch_size + 1, stride):
            patch = img[y:y+patch_size, x:x+patch_size]
            patches.append(patch)
            coords.append((y, x))

    patches = np.stack(patches, axis=0)
    coords = np.array(coords)
    return patches, coords

# test
patches, coords = extract_patches(img, patch_size=64, stride=32)
print("圖被切成幾個 patch :", patches.shape[0])
print("每個 patch 尺寸:", patches.shape[1:])

# 看幾個 patch
fig, axes = plt.subplots(1, 5, figsize=(12, 3))
for i, ax in enumerate(axes):
    ax.imshow(patches[i], cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 圖被切成幾個 patch : 1386
# 每個 patch 尺寸: (64, 64)

# %% [markdown]
# 3. 切整個 Dataset 的 patch

# %%
import numpy as np
import cv2
from pathlib import Path
import matplotlib.pyplot as plt

# %%
DATA_ROOT = Path("/content/grainsize_dataset")  # 你的 dataset 資料夾路徑
IMG_EXT = [".jpg", ".png", ".jpeg", ".tif", ".tiff"]

image_paths = [p for p in DATA_ROOT.rglob("*") if p.suffix.lower() in IMG_EXT]

print("找到影像數量:", len(image_paths))
image_paths[:5]
# Out:
# 找到影像數量: 4222
# [PosixPath('/content/grainsize_dataset/train/10.0/152-100-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/126-102-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/146-101-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/194-101-10.0-500x.jpg'),
#  PosixPath('/content/grainsize_dataset/train/10.0/182-101-10.0-500x.jpg')]

# %%
def preprocess_image(path, resize_to=None):
    img = cv2.imread(str(path), cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Cannot read image: {path}")
    img = img.astype(np.float32) / 255.0
    if resize_to is not None:
        img = cv2.resize(img, resize_to, interpolation=cv2.INTER_AREA)
    return img


def extract_patches(img, patch_size=64, stride=32):
    H, W = img.shape
    patches = []
    coords = []
    for y in range(0, H - patch_size + 1, stride):
        for x in range(0, W - patch_size + 1, stride):
            patch = img[y:y+patch_size, x:x+patch_size]
            patches.append(patch)
            coords.append((y, x))
    return np.stack(patches), np.array(coords)

# %%
import cv2
import numpy as np
from pathlib import Path

DATA_ROOT = Path("/content/grainsize_dataset")
IMG_EXT = [".jpg", ".png", ".jpeg", ".tif", ".tiff"]

image_paths = [p for p in DATA_ROOT.rglob("*") if p.suffix.lower() in IMG_EXT]
print("找到影像數量:", len(image_paths))

def preprocess_image(path, resize_to=(512, 512)):
    img = cv2.imread(str(path), cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Cannot read image: {path}")
    img = cv2.resize(img, resize_to, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0
    return img

def extract_patches(img, patch_size=64, stride=32):
    H, W = img.shape
    patches = []
    coords = []
    for y in range(0, H - patch_size + 1, stride):
        for x in range(0, W - patch_size + 1, stride):
            patch = img[y:y+patch_size, x:x+patch_size]
            patches.append(patch)
            coords.append((y, x))
    return np.stack(patches), np.array(coords)
# Out:
# 找到影像數量: 4222

# %%
PATCH_SIZE = 64
STRIDE = 32
MAX_PATCHES_TOTAL = 80000

all_patches = []
meta_info = []

total_patches = 0

for img_id, path in enumerate(image_paths):
    img = preprocess_image(path, resize_to=(512, 512))
    patches, coords = extract_patches(img, patch_size=PATCH_SIZE, stride=STRIDE)

    if total_patches + patches.shape[0] > MAX_PATCHES_TOTAL:
        remain = MAX_PATCHES_TOTAL - total_patches
        if remain <= 0:
            break
        patches = patches[:remain]
        coords = coords[:remain]

    # 降成 float16 省記憶體 爆掉了
    patches = patches.astype(np.float16)

    all_patches.append(patches)
    img_ids = np.full((coords.shape[0], 1), img_id, dtype=np.int32)
    meta = np.hstack([img_ids, coords])
    meta_info.append(meta)

    total_patches += patches.shape[0]

    print(f"處理到第 {img_id} 張圖，累積 patch 數: {total_patches}")

    if total_patches >= MAX_PATCHES_TOTAL:
        break

all_patches = np.concatenate(all_patches, axis=0)   # (N, 64, 64)
meta_info  = np.concatenate(meta_info, axis=0)      # (N, 3)

print("總共 patch 數量:", all_patches.shape[0])
print("meta_info 形狀:", meta_info.shape)

# 加 channel 維度
patches = all_patches[..., np.newaxis]  # (N, 64, 64, 1)
meta    = meta_info
print("patches 形狀:", patches.shape)
# Out:
# 處理到第 0 張圖，累積 patch 數: 225
# 處理到第 1 張圖，累積 patch 數: 450
# 處理到第 2 張圖，累積 patch 數: 675
# 處理到第 3 張圖，累積 patch 數: 900
# 處理到第 4 張圖，累積 patch 數: 1125
# 處理到第 5 張圖，累積 patch 數: 1350
# 處理到第 6 張圖，累積 patch 數: 1575
# 處理到第 7 張圖，累積 patch 數: 1800
# 處理到第 8 張圖，累積 patch 數: 2025
# 處理到第 9 張圖，累積 patch 數: 2250
# 處理到第 10 張圖，累積 patch 數: 2475
# 處理到第 11 張圖，累積 patch 數: 2700
# 處理到第 12 張圖，累積 patch 數: 2925
# 處理到第 13 張圖，累積 patch 數: 3150
# 處理到第 14 張圖，累積 patch 數: 3375
# 處理到第 15 張圖，累積 patch 數: 3600
# 處理到第 16 張圖，累積 patch 數: 3825
# 處理到第 17 張圖，累積 patch 數: 4050
# 處理到第 18 張圖，累積 patch 數: 4275
# 處理到第 19 張圖，累積 patch 數: 4500
# 處理到第 20 張圖，累積 patch 數: 4725
# 處理到第 21 張圖，累積 patch 數: 4950
# 處理到第 22 張圖，累積 patch 數: 5175
# 處理到第 23 張圖，累積 patch 數: 5400
# 處理到第 24 張圖，累積 patch 數: 5625
# 處理到第 25 張圖，累積 patch 數: 5850
# 處理到第 26 張圖，累積 patch 數: 6075
# 處理到第 27 張圖，累積 patch 數: 6300
# 處理到第 28 張圖，累積 patch 數: 6525
# 處理到第 29 張圖，累積 patch 數: 6750
# 處理到第 30 張圖，累積 patch 數: 6975
# 處理到第 31 張圖，累積 patch 數: 7200
# 處理到第 32 張圖，累積 patch 數: 7425
# 處理到第 33 張圖，累積 patch 數: 7650
# 處理到第 34 張圖，累積 patch 數: 7875
# 處理到第 35 張圖，累積 patch 數: 8100
# 處理到第 36 張圖，累積 patch 數: 8325
# 處理到第 37 張圖，累積 patch 數: 8550
# 處理到第 38 張圖，累積 patch 數: 8775
# 處理到第 39 張圖，累積 patch 數: 9000
# 處理到第 40 張圖，累積 patch 數: 9225
# 處理到第 41 張圖，累積 patch 數: 9450
# 處理到第 42 張圖，累積 patch 數: 9675
# 處理到第 43 張圖，累積 patch 數: 9900
# 處理到第 44 張圖，累積 patch 數: 10125
# 處理到第 45 張圖，累積 patch 數: 10350
# 處理到第 46 張圖，累積 patch 數: 10575
# 處理到第 47 張圖，累積 patch 數: 10800
# 處理到第 48 張圖，累積 patch 數: 11025
# 處理到第 49 張圖，累積 patch 數: 11250
# 處理到第 50 張圖，累積 patch 數: 11475
# 處理到第 51 張圖，累積 patch 數: 11700
# 處理到第 52 張圖，累積 patch 數: 11925
# 處理到第 53 張圖，累積 patch 數: 12150
# 處理到第 54 張圖，累積 patch 數: 12375
# 處理到第 55 張圖，累積 patch 數: 12600
# 處理到第 56 張圖，累積 patch 數: 12825
# 處理到第 57 張圖，累積 patch 數: 13050
# 處理到第 58 張圖，累積 patch 數: 13275
# 處理到第 59 張圖，累積 patch 數: 13500
# 處理到第 60 張圖，累積 patch 數: 13725
# 處理到第 61 張圖，累積 patch 數: 13950
# 處理到第 62 張圖，累積 patch 數: 14175
# 處理到第 63 張圖，累積 patch 數: 14400
# 處理到第 64 張圖，累積 patch 數: 14625
# 處理到第 65 張圖，累積 patch 數: 14850
# 處理到第 66 張圖，累積 patch 數: 15075
# 處理到第 67 張圖，累積 patch 數: 15300
# 處理到第 68 張圖，累積 patch 數: 15525
# 處理到第 69 張圖，累積 patch 數: 15750
# 處理到第 70 張圖，累積 patch 數: 15975
# 處理到第 71 張圖，累積 patch 數: 16200
# 處理到第 72 張圖，累積 patch 數: 16425
# 處理到第 73 張圖，累積 patch 數: 16650
# 處理到第 74 張圖，累積 patch 數: 16875
# 處理到第 75 張圖，累積 patch 數: 17100
# 處理到第 76 張圖，累積 patch 數: 17325
# 處理到第 77 張圖，累積 patch 數: 17550
# 處理到第 78 張圖，累積 patch 數: 17775
# 處理到第 79 張圖，累積 patch 數: 18000
# 處理到第 80 張圖，累積 patch 數: 18225
# 處理到第 81 張圖，累積 patch 數: 18450
# 處理到第 82 張圖，累積 patch 數: 18675
# 處理到第 83 張圖，累積 patch 數: 18900
# 處理到第 84 張圖，累積 patch 數: 19125
# 處理到第 85 張圖，累積 patch 數: 19350
# 處理到第 86 張圖，累積 patch 數: 19575
# 處理到第 87 張圖，累積 patch 數: 19800
# 處理到第 88 張圖，累積 patch 數: 20025
# 處理到第 89 張圖，累積 patch 數: 20250
# 處理到第 90 張圖，累積 patch 數: 20475
# 處理到第 91 張圖，累積 patch 數: 20700
# 處理到第 92 張圖，累積 patch 數: 20925
# 處理到第 93 張圖，累積 patch 數: 21150
# 處理到第 94 張圖，累積 patch 數: 21375
# 處理到第 95 張圖，累積 patch 數: 21600
# 處理到第 96 張圖，累積 patch 數: 21825
# 處理到第 97 張圖，累積 patch 數: 22050
# 處理到第 98 張圖，累積 patch 數: 22275
# 處理到第 99 張圖，累積 patch 數: 22500
# 處理到第 100 張圖，累積 patch 數: 22725
# 處理到第 101 張圖，累積 patch 數: 22950
# 處理到第 102 張圖，累積 patch 數: 23175
# 處理到第 103 張圖，累積 patch 數: 23400
# 處理到第 104 張圖，累積 patch 數: 23625
# 處理到第 105 張圖，累積 patch 數: 23850
# 處理到第 106 張圖，累積 patch 數: 24075
# 處理到第 107 張圖，累積 patch 數: 24300
# 處理到第 108 張圖，累積 patch 數: 24525
# 處理到第 109 張圖，累積 patch 數: 24750
# 處理到第 110 張圖，累積 patch 數: 24975
# 處理到第 111 張圖，累積 patch 數: 25200
# 處理到第 112 張圖，累積 patch 數: 25425
# 處理到第 113 張圖，累積 patch 數: 25650
# 處理到第 114 張圖，累積 patch 數: 25875
# 處理到第 115 張圖，累積 patch 數: 26100
# 處理到第 116 張圖，累積 patch 數: 26325
# 處理到第 117 張圖，累積 patch 數: 26550
# 處理到第 118 張圖，累積 patch 數: 26775
# 處理到第 119 張圖，累積 patch 數: 27000
# 處理到第 120 張圖，累積 patch 數: 27225
# 處理到第 121 張圖，累積 patch 數: 27450
# 處理到第 122 張圖，累積 patch 數: 27675
# 處理到第 123 張圖，累積 patch 數: 27900
# 處理到第 124 張圖，累積 patch 數: 28125
# 處理到第 125 張圖，累積 patch 數: 28350
# 處理到第 126 張圖，累積 patch 數: 28575
# 處理到第 127 張圖，累積 patch 數: 28800
# 處理到第 128 張圖，累積 patch 數: 29025
# 處理到第 129 張圖，累積 patch 數: 29250
# 處理到第 130 張圖，累積 patch 數: 29475
# 處理到第 131 張圖，累積 patch 數: 29700
# 處理到第 132 張圖，累積 patch 數: 29925
# 處理到第 133 張圖，累積 patch 數: 30150
# 處理到第 134 張圖，累積 patch 數: 30375
# 處理到第 135 張圖，累積 patch 數: 30600
# 處理到第 136 張圖，累積 patch 數: 30825
# 處理到第 137 張圖，累積 patch 數: 31050
# 處理到第 138 張圖，累積 patch 數: 31275
# 處理到第 139 張圖，累積 patch 數: 31500
# 處理到第 140 張圖，累積 patch 數: 31725
# 處理到第 141 張圖，累積 patch 數: 31950
# 處理到第 142 張圖，累積 patch 數: 32175
# 處理到第 143 張圖，累積 patch 數: 32400
# 處理到第 144 張圖，累積 patch 數: 32625
# 處理到第 145 張圖，累積 patch 數: 32850
# 處理到第 146 張圖，累積 patch 數: 33075
# 處理到第 147 張圖，累積 patch 數: 33300
# 處理到第 148 張圖，累積 patch 數: 33525
# 處理到第 149 張圖，累積 patch 數: 33750
# 處理到第 150 張圖，累積 patch 數: 33975
# 處理到第 151 張圖，累積 patch 數: 34200
# 處理到第 152 張圖，累積 patch 數: 34425
# 處理到第 153 張圖，累積 patch 數: 34650
# 處理到第 154 張圖，累積 patch 數: 34875
# 處理到第 155 張圖，累積 patch 數: 35100
# 處理到第 156 張圖，累積 patch 數: 35325
# 處理到第 157 張圖，累積 patch 數: 35550
# 處理到第 158 張圖，累積 patch 數: 35775
# 處理到第 159 張圖，累積 patch 數: 36000
# 處理到第 160 張圖，累積 patch 數: 36225
# 處理到第 161 張圖，累積 patch 數: 36450
# 處理到第 162 張圖，累積 patch 數: 36675
# 處理到第 163 張圖，累積 patch 數: 36900
# 處理到第 164 張圖，累積 patch 數: 37125
# 處理到第 165 張圖，累積 patch 數: 37350
# 處理到第 166 張圖，累積 patch 數: 37575
# 處理到第 167 張圖，累積 patch 數: 37800
# 處理到第 168 張圖，累積 patch 數: 38025
# 處理到第 169 張圖，累積 patch 數: 38250
# 處理到第 170 張圖，累積 patch 數: 38475
# 處理到第 171 張圖，累積 patch 數: 38700
# 處理到第 172 張圖，累積 patch 數: 38925
# 處理到第 173 張圖，累積 patch 數: 39150
# 處理到第 174 張圖，累積 patch 數: 39375
# 處理到第 175 張圖，累積 patch 數: 39600
# 處理到第 176 張圖，累積 patch 數: 39825
# 處理到第 177 張圖，累積 patch 數: 40050
# 處理到第 178 張圖，累積 patch 數: 40275
# 處理到第 179 張圖，累積 patch 數: 40500
# 處理到第 180 張圖，累積 patch 數: 40725
# 處理到第 181 張圖，累積 patch 數: 40950
# 處理到第 182 張圖，累積 patch 數: 41175
# 處理到第 183 張圖，累積 patch 數: 41400
# 處理到第 184 張圖，累積 patch 數: 41625
# 處理到第 185 張圖，累積 patch 數: 41850
# 處理到第 186 張圖，累積 patch 數: 42075
# 處理到第 187 張圖，累積 patch 數: 42300
# 處理到第 188 張圖，累積 patch 數: 42525
# 處理到第 189 張圖，累積 patch 數: 42750
# 處理到第 190 張圖，累積 patch 數: 42975
# 處理到第 191 張圖，累積 patch 數: 43200
# 處理到第 192 張圖，累積 patch 數: 43425
# 處理到第 193 張圖，累積 patch 數: 43650
# 處理到第 194 張圖，累積 patch 數: 43875
# 處理到第 195 張圖，累積 patch 數: 44100
# 處理到第 196 張圖，累積 patch 數: 44325
# 處理到第 197 張圖，累積 patch 數: 44550
# 處理到第 198 張圖，累積 patch 數: 44775
# 處理到第 199 張圖，累積 patch 數: 45000
# 處理到第 200 張圖，累積 patch 數: 45225
# 處理到第 201 張圖，累積 patch 數: 45450
# 處理到第 202 張圖，累積 patch 數: 45675
# 處理到第 203 張圖，累積 patch 數: 45900
# 處理到第 204 張圖，累積 patch 數: 46125
# 處理到第 205 張圖，累積 patch 數: 46350
# 處理到第 206 張圖，累積 patch 數: 46575
# 處理到第 207 張圖，累積 patch 數: 46800
# 處理到第 208 張圖，累積 patch 數: 47025
# 處理到第 209 張圖，累積 patch 數: 47250
# 處理到第 210 張圖，累積 patch 數: 47475
# 處理到第 211 張圖，累積 patch 數: 47700
# 處理到第 212 張圖，累積 patch 數: 47925
# 處理到第 213 張圖，累積 patch 數: 48150
# 處理到第 214 張圖，累積 patch 數: 48375
# 處理到第 215 張圖，累積 patch 數: 48600
# 處理到第 216 張圖，累積 patch 數: 48825
# 處理到第 217 張圖，累積 patch 數: 49050
# 處理到第 218 張圖，累積 patch 數: 49275
# 處理到第 219 張圖，累積 patch 數: 49500
# 處理到第 220 張圖，累積 patch 數: 49725
# 處理到第 221 張圖，累積 patch 數: 49950
# 處理到第 222 張圖，累積 patch 數: 50175
# 處理到第 223 張圖，累積 patch 數: 50400
# 處理到第 224 張圖，累積 patch 數: 50625
# 處理到第 225 張圖，累積 patch 數: 50850
# 處理到第 226 張圖，累積 patch 數: 51075
# 處理到第 227 張圖，累積 patch 數: 51300
# 處理到第 228 張圖，累積 patch 數: 51525
# 處理到第 229 張圖，累積 patch 數: 51750
# 處理到第 230 張圖，累積 patch 數: 51975
# 處理到第 231 張圖，累積 patch 數: 52200
# 處理到第 232 張圖，累積 patch 數: 52425
# 處理到第 233 張圖，累積 patch 數: 52650
# 處理到第 234 張圖，累積 patch 數: 52875
# 處理到第 235 張圖，累積 patch 數: 53100
# 處理到第 236 張圖，累積 patch 數: 53325
# 處理到第 237 張圖，累積 patch 數: 53550
# 處理到第 238 張圖，累積 patch 數: 53775
# 處理到第 239 張圖，累積 patch 數: 54000
# 處理到第 240 張圖，累積 patch 數: 54225
# 處理到第 241 張圖，累積 patch 數: 54450
# 處理到第 242 張圖，累積 patch 數: 54675
# 處理到第 243 張圖，累積 patch 數: 54900
# 處理到第 244 張圖，累積 patch 數: 55125
# 處理到第 245 張圖，累積 patch 數: 55350
# 處理到第 246 張圖，累積 patch 數: 55575
# 處理到第 247 張圖，累積 patch 數: 55800
# 處理到第 248 張圖，累積 patch 數: 56025
# 處理到第 249 張圖，累積 patch 數: 56250
# 處理到第 250 張圖，累積 patch 數: 56475
# 處理到第 251 張圖，累積 patch 數: 56700
# 處理到第 252 張圖，累積 patch 數: 56925
# 處理到第 253 張圖，累積 patch 數: 57150
# 處理到第 254 張圖，累積 patch 數: 57375
# 處理到第 255 張圖，累積 patch 數: 57600
# 處理到第 256 張圖，累積 patch 數: 57825
# 處理到第 257 張圖，累積 patch 數: 58050
# 處理到第 258 張圖，累積 patch 數: 58275
# 處理到第 259 張圖，累積 patch 數: 58500
# 處理到第 260 張圖，累積 patch 數: 58725
# 處理到第 261 張圖，累積 patch 數: 58950
# 處理到第 262 張圖，累積 patch 數: 59175
# 處理到第 263 張圖，累積 patch 數: 59400
# 處理到第 264 張圖，累積 patch 數: 59625
# 處理到第 265 張圖，累積 patch 數: 59850
# 處理到第 266 張圖，累積 patch 數: 60075
# 處理到第 267 張圖，累積 patch 數: 60300
# 處理到第 268 張圖，累積 patch 數: 60525
# 處理到第 269 張圖，累積 patch 數: 60750
# 處理到第 270 張圖，累積 patch 數: 60975
# 處理到第 271 張圖，累積 patch 數: 61200
# 處理到第 272 張圖，累積 patch 數: 61425
# 處理到第 273 張圖，累積 patch 數: 61650
# 處理到第 274 張圖，累積 patch 數: 61875
# 處理到第 275 張圖，累積 patch 數: 62100
# 處理到第 276 張圖，累積 patch 數: 62325
# 處理到第 277 張圖，累積 patch 數: 62550
# 處理到第 278 張圖，累積 patch 數: 62775
# 處理到第 279 張圖，累積 patch 數: 63000
# 處理到第 280 張圖，累積 patch 數: 63225
# 處理到第 281 張圖，累積 patch 數: 63450
# 處理到第 282 張圖，累積 patch 數: 63675
# 處理到第 283 張圖，累積 patch 數: 63900
# 處理到第 284 張圖，累積 patch 數: 64125
# 處理到第 285 張圖，累積 patch 數: 64350
# 處理到第 286 張圖，累積 patch 數: 64575
# 處理到第 287 張圖，累積 patch 數: 64800
# 處理到第 288 張圖，累積 patch 數: 65025
# 處理到第 289 張圖，累積 patch 數: 65250
# 處理到第 290 張圖，累積 patch 數: 65475
# 處理到第 291 張圖，累積 patch 數: 65700
# 處理到第 292 張圖，累積 patch 數: 65925
# 處理到第 293 張圖，累積 patch 數: 66150
# 處理到第 294 張圖，累積 patch 數: 66375
# 處理到第 295 張圖，累積 patch 數: 66600
# 處理到第 296 張圖，累積 patch 數: 66825
# 處理到第 297 張圖，累積 patch 數: 67050
# 處理到第 298 張圖，累積 patch 數: 67275
# 處理到第 299 張圖，累積 patch 數: 67500
# 處理到第 300 張圖，累積 patch 數: 67725
# 處理到第 301 張圖，累積 patch 數: 67950
# 處理到第 302 張圖，累積 patch 數: 68175
# 處理到第 303 張圖，累積 patch 數: 68400
# 處理到第 304 張圖，累積 patch 數: 68625
# 處理到第 305 張圖，累積 patch 數: 68850
# 處理到第 306 張圖，累積 patch 數: 69075
# 處理到第 307 張圖，累積 patch 數: 69300
# 處理到第 308 張圖，累積 patch 數: 69525
# 處理到第 309 張圖，累積 patch 數: 69750
# 處理到第 310 張圖，累積 patch 數: 69975
# 處理到第 311 張圖，累積 patch 數: 70200
# 處理到第 312 張圖，累積 patch 數: 70425
# 處理到第 313 張圖，累積 patch 數: 70650
# 處理到第 314 張圖，累積 patch 數: 70875
# 處理到第 315 張圖，累積 patch 數: 71100
# 處理到第 316 張圖，累積 patch 數: 71325
# 處理到第 317 張圖，累積 patch 數: 71550
# 處理到第 318 張圖，累積 patch 數: 71775
# 處理到第 319 張圖，累積 patch 數: 72000
# 處理到第 320 張圖，累積 patch 數: 72225
# 處理到第 321 張圖，累積 patch 數: 72450
# 處理到第 322 張圖，累積 patch 數: 72675
# 處理到第 323 張圖，累積 patch 數: 72900
# 處理到第 324 張圖，累積 patch 數: 73125
# 處理到第 325 張圖，累積 patch 數: 73350
# 處理到第 326 張圖，累積 patch 數: 73575
# 處理到第 327 張圖，累積 patch 數: 73800
# 處理到第 328 張圖，累積 patch 數: 74025
# 處理到第 329 張圖，累積 patch 數: 74250
# 處理到第 330 張圖，累積 patch 數: 74475
# 處理到第 331 張圖，累積 patch 數: 74700
# 處理到第 332 張圖，累積 patch 數: 74925
# 處理到第 333 張圖，累積 patch 數: 75150
# 處理到第 334 張圖，累積 patch 數: 75375
# 處理到第 335 張圖，累積 patch 數: 75600
# 處理到第 336 張圖，累積 patch 數: 75825
# 處理到第 337 張圖，累積 patch 數: 76050
# 處理到第 338 張圖，累積 patch 數: 76275
# 處理到第 339 張圖，累積 patch 數: 76500
# 處理到第 340 張圖，累積 patch 數: 76725
# 處理到第 341 張圖，累積 patch 數: 76950
# 處理到第 342 張圖，累積 patch 數: 77175
# 處理到第 343 張圖，累積 patch 數: 77400
# 處理到第 344 張圖，累積 patch 數: 77625
# 處理到第 345 張圖，累積 patch 數: 77850
# 處理到第 346 張圖，累積 patch 數: 78075
# 處理到第 347 張圖，累積 patch 數: 78300
# 處理到第 348 張圖，累積 patch 數: 78525
# 處理到第 349 張圖，累積 patch 數: 78750
# 處理到第 350 張圖，累積 patch 數: 78975
# 處理到第 351 張圖，累積 patch 數: 79200
# 處理到第 352 張圖，累積 patch 數: 79425
# 處理到第 353 張圖，累積 patch 數: 79650
# 處理到第 354 張圖，累積 patch 數: 79875
# 處理到第 355 張圖，累積 patch 數: 80000
# 總共 patch 數量: 80000
# meta_info 形狀: (80000, 3)
# patches 形狀: (80000, 64, 64, 1)

# %% [markdown]
# PCA + K-means 無監督分群
#  準備資料（攤平 + 抽樣）
#
# 為了省 RAM，我們只用最多 30,000 個 patch 來做 PCA + clustering。

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import numpy as np

MAX_SAMPLES_PCA = 30000
N = min(patches.shape[0], MAX_SAMPLES_PCA)

X = patches[:N]               # (N, 64, 64, 1)
X_flat = X.reshape(N, -1)     # (N, 4096)

print("PCA 使用 patch 數:", N, "，每個維度:", X_flat.shape[1])
# Out:
# PCA 使用 patch 數: 30000 ，每個維度: 4096

# %% [markdown]
# 標準化 + PCA 降維

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat)

# 降到 50 維
pca_50 = PCA(n_components=50, random_state=42)
X_pca50 = pca_50.fit_transform(X_scaled)

# 降到 2 維
pca_2 = PCA(n_components=2, random_state=42)
X_pca2 = pca_2.fit_transform(X_scaled)

print("PCA50:", X_pca50.shape, "  PCA2:", X_pca2.shape)
# Out:
# PCA50: (30000, 50)   PCA2: (30000, 2)

# %% [markdown]
# 分群 + visualize

# %%
import matplotlib.pyplot as plt

K = 5  # 分5群結果最適合
kmeans = KMeans(n_clusters=K, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_pca50)

print("各群大小:", np.bincount(clusters))

plt.figure(figsize=(6,5))
for k in range(K):
    idx = (clusters == k)
    plt.scatter(X_pca2[idx, 0], X_pca2[idx, 1], s=3, alpha=0.5, label=f"C{k}")
plt.legend(markerscale=3)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA 2D + K-means Clusters")
plt.show()
# Out:
# 各群大小: [ 5458  5301 12787  2608  3846]

# %% [markdown]
# Step 1 — flatten + PCA + K-means

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import numpy as np

# 將 patch (N, 64, 64, 1) → (N, 4096)
patches_flat = patches.reshape(patches.shape[0], -1)

# PCA 降維
pca = PCA(n_components=50, random_state=42)
patches_pca = pca.fit_transform(patches_flat)

# 分群
kmeans = KMeans(n_clusters=5, random_state=42)
cluster_labels = kmeans.fit_predict(patches_pca)

print("分群完成")
print("各群數量：", np.bincount(cluster_labels))
# Out:
# 分群完成
# 各群數量： [10550 14744 14140  7154 33412]

# %% [markdown]
# Step 2 — 抽取每群 25 個 patch 作為代表

# %%
import random

samples_per_cluster = 25
cluster_samples = {}

for c in range(5):
    idx = np.where(cluster_labels == c)[0]
    chosen = np.random.choice(idx, samples_per_cluster, replace=False)
    cluster_samples[c] = patches[chosen]

# %% [markdown]
# Step 3 — 畫出 5*5 的代表圖（共五張圖，每張代表一群）

# %%
import matplotlib.pyplot as plt

for c in range(5):
    fig, axes = plt.subplots(5, 5, figsize=(6, 6))
    fig.suptitle(f"Cluster {c} Representative Patches", fontsize=16)

    for i in range(25):
        ax = axes[i//5, i%5]
        ax.imshow(cluster_samples[c][i].squeeze(), cmap='gray')
        ax.axis('off')

    plt.show()

# %% [markdown]
# A4. 看每個 cluster 的代表 patch

# %%
def show_cluster_examples(cluster_id, num_examples=8):
    idx = np.where(clusters == cluster_id)[0]
    if len(idx) == 0:
        print(f"Cluster {cluster_id} 沒有樣本")
        return
    choose = np.random.choice(idx, size=min(num_examples, len(idx)), replace=False)
    imgs = X[choose, :, :, 0]

    cols = 4
    rows = int(np.ceil(len(imgs) / cols))
    plt.figure(figsize=(3*cols, 3*rows))
    for i, img in enumerate(imgs):
        plt.subplot(rows, cols, i+1)
        plt.imshow(img, cmap='gray')
        plt.axis('off')
    plt.suptitle(f"Cluster {cluster_id} examples")
    plt.show()

for k in range(K):
    show_cluster_examples(k)

# %% [markdown]
# A5. 把 cluster 畫回某張 SEM 圖（cluster map）

# %%
import cv2
from pathlib import Path

DATA_ROOT = Path("/content/grainsize_dataset")
IMG_EXT = [".jpg", ".png", ".jpeg", ".tif", ".tiff"]
image_paths = [p for p in DATA_ROOT.rglob("*") if p.suffix.lower() in IMG_EXT]

# 只對前 N 個 patch 有 cluster 標籤
meta_used = meta[:N]

IMG_ID = 0

mask_img = (meta_used[:, 0] == IMG_ID)
coords_img = meta_used[mask_img][:, 1:3]   # (M, 2)
clusters_img = clusters[mask_img]          # (M,)

print("這張圖的 patch 數:", len(clusters_img))

# 讀並 resize 成 512x512 (重要)
orig = cv2.imread(str(image_paths[IMG_ID]), cv2.IMREAD_GRAYSCALE).astype(np.float32) / 255.0
orig = cv2.resize(orig, (512, 512), interpolation=cv2.INTER_AREA)
H, W = orig.shape

cluster_map = -1 * np.ones((H, W), dtype=int)
PATCH_SIZE = 64
STRIDE = 32

for (y, x), c in zip(coords_img, clusters_img):
    cluster_map[y:y+PATCH_SIZE, x:x+PATCH_SIZE] = c

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title("Original (resized)")
plt.imshow(orig, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Cluster Map")
plt.imshow(cluster_map, cmap='tab10', interpolation='nearest')
plt.axis('off')
plt.show()
# Out:
# 這張圖的 patch 數: 225

# %% [markdown]
# Part B：Autoencoder + Reconstruction Error Heatmap
# B1. 準備訓練資料（轉回 float32）
#
# 我們用全部 80k patch 訓練也 OK，如果你覺得太慢，可以只用 60k 左右。

# %%
from sklearn.model_selection import train_test_split

X_all = patches.astype(np.float32)

MAX_TRAIN = 20000  #60000改20000(加快速度)
N_train_use = min(X_all.shape[0], MAX_TRAIN)
X_sub = X_all[:N_train_use]

X_train, X_val = train_test_split(X_sub, test_size=0.1, random_state=42)
print("Train:", X_train.shape, " Val:", X_val.shape)
# Out:
# Train: (18000, 64, 64, 1)  Val: (2000, 64, 64, 1)

# %% [markdown]
# B2. 建立 Autoencoder 模型並訓練

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

input_shape = (64, 64, 1)

inp = layers.Input(shape=input_shape)
x = layers.Conv2D(32, (3,3), padding='same', activation='relu')(inp)
x = layers.MaxPool2D((2,2))(x)              # 32x32
x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(x)
x = layers.MaxPool2D((2,2))(x)              # 16x16
x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
encoded = layers.MaxPool2D((2,2))(x)        # 8x8x128

x = layers.Conv2DTranspose(128, (3,3), strides=2, padding='same', activation='relu')(encoded) # 16x16
x = layers.Conv2DTranspose(64, (3,3), strides=2, padding='same', activation='relu')(x)        # 32x32
x = layers.Conv2DTranspose(32, (3,3), strides=2, padding='same', activation='relu')(x)        # 64x64
decoded = layers.Conv2D(1, (3,3), padding='same', activation='sigmoid')(x)

autoencoder = models.Model(inp, decoded)
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss='mse')
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 16, 16, 128)    │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 32, 32, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 64, 64, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332,801 (1.27 MB)
#  Trainable params: 332,801 (1.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=10, restore_best_weights=True
    )
]

history = autoencoder.fit(
    X_train, X_train,
    validation_data=(X_val, X_val),
    epochs=15,#100改15
    batch_size=256,
    shuffle=True,
    callbacks=callbacks
)
# Out:
# Epoch 1/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 349s 5s/step - loss: 0.0378 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 2/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 374s 5s/step - loss: 0.0160 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 3/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 389s 5s/step - loss: 0.0044 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 4/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 341s 5s/step - loss: 0.0029 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 5/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 335s 5s/step - loss: 0.0023 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 6/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 340s 5s/step - loss: 0.0020 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 7/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 335s 5s/step - loss: 0.0017 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 8/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 330s 5s/step - loss: 0.0016 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 9/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 345s 5s/step - loss: 0.0014 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 10/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 372s 5s/step - loss: 0.0014 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 11/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 389s 5s/step - loss: 0.0013 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 12/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 332s 5s/step - loss: 0.0013 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 13/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 384s 5s/step - loss: 0.0013 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 14/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 392s 5s/step - loss: 0.0013 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 15/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 399s 5s/step - loss: 0.0011 - val_loss: 0.0012 - learning_rate: 0.0010

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epoch')
plt.ylabel('MSE loss')
plt.legend()
plt.title('Autoencoder training')
plt.show()

# %% [markdown]
# B3. 對某張圖做 reconstruction error heatmap

# %%
import cv2

def compute_recon_error_for_image(img_id, patches_all, meta_all, model,
                                  patch_size=64):
    # 找出屬於這張圖的 patch
    mask = (meta_all[:, 0] == img_id)
    coords = meta_all[mask][:, 1:3]
    patches_img = patches_all[mask]   # (M, 64, 64, 1)
    if patches_img.shape[0] == 0:
        raise ValueError(f"img_id {img_id} 沒有對應的 patch（因為前面截斷在 80k）")

    # AE 重建
    recon = model.predict(patches_img, batch_size=256, verbose=0)
    errors = np.mean((patches_img - recon)**2, axis=(1,2,3))  # (M,)

    # 讀原圖（resize 成 512x512，跟當初切 patch 一致）
    orig = cv2.imread(str(image_paths[img_id]), cv2.IMREAD_GRAYSCALE).astype(np.float32) / 255.0
    orig = cv2.resize(orig, (512, 512), interpolation=cv2.INTER_AREA)
    H, W = orig.shape

    error_map = np.zeros((H, W), dtype=np.float32)
    count_map = np.zeros((H, W), dtype=np.float32)

    for (y, x), e in zip(coords, errors):
        error_map[y:y+patch_size, x:x+patch_size] += e
        count_map[y:y+patch_size, x:x+patch_size] += 1.0

    count_map[count_map == 0] = 1.0
    error_map /= count_map

    return orig, error_map

# %% [markdown]
# B4. 畫 heatmap + 疊圖 + binary defect mask

# %%
IMG_ID = 50  # 想看哪一張換這裡

orig, error_map = compute_recon_error_for_image(
    img_id=IMG_ID,
    patches_all=patches.astype(np.float32),  # AE 推論用 float32
    meta_all=meta,
    model=autoencoder,
    patch_size=64
)

# 正規化到 0-1
em_norm = (error_map - error_map.min()) / (error_map.max() - error_map.min() + 1e-8)

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.title("Original")
plt.imshow(orig, cmap='gray')
plt.axis('off')

plt.subplot(1,3,2)
plt.title("Error Map")
plt.imshow(em_norm, cmap='inferno')
plt.colorbar(fraction=0.046, pad=0.04)
plt.axis('off')

plt.subplot(1,3,3)
plt.title("Overlay")
plt.imshow(orig, cmap='gray')
plt.imshow(em_norm, cmap='inferno', alpha=0.5)
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3003581064.py in <cell line: 0>()
#       1 IMG_ID = 50  # 想看哪一張換這裡
#       2
# ----> 3 orig, error_map = compute_recon_error_for_image(
#       4     img_id=IMG_ID,
#       5     patches_all=patches.astype(np.float32),  # AE 推論用 float32
#
# NameError: name 'compute_recon_error_for_image' is not defined

# %% [markdown]
# 如果想看「二值化缺陷區」：

# %%
threshold = np.quantile(error_map, 0.95)  # 取 error 前 5% 當 anomaly
defect_mask = (error_map >= threshold)

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(orig, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Defect Mask (top 5% error)")
plt.imshow(defect_mask, cmap='gray')
plt.axis('off')
plt.show()
